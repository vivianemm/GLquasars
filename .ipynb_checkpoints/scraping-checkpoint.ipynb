# %%
! pip install requests --user
! pip install beautifulsoup4 --user
! pip install selenium --user

! pip install lxml --user

! pip install numpy --user
! pip install pandas --user
! pip install astropy --user
# ! pip install matplotlib
# Out:
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.1, however version 19.2.3 is available.
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get("https://www.cfa.harvard.edu/castles/")
soup = BeautifulSoup(page.text, 'html.parser')

# %%
tables = soup.find_all('table')  # bs4.element.ResultSet
len(tables)
# Out:
# 3

# %%
tables = list(tables)
list_tables_df = []

for table in tables:
    
    headers = [header.text for header in table.find_all('th')]
        
    tr = table.find_all('tr')
    text_list = []
    
    for row in tr:
        td = row.find_all('td')
        text = [row.text for row in td]
        text_list.append(text)
     
    if len(headers) != 0:
        df = pd.DataFrame(text_list, columns=headers)
    else:
        df = pd.DataFrame(text_list)
        
    list_tables_df.append(df)


list_tables_df[2]
# Out:
#        # Image    Binary Name     G     zs  RA (J2000)  Dec (J2000)  E(B-V)  \
# 0   None  None           None  None   None         None         None   None
# 1      1        LBQS0015+0239     B   2.45  00:18:11.37  +02:56:39.4  0.030
# 2      2           MG0023+171     B   0.95  00:25:37.09  +17:28:02.5  0.054
# 3      3        LBQS0103-2753     B   0.85  01:05:34.74  -27:36:58.5  0.020
# 4      4            Q0151+048     A   1.91  01:53:53.87  +05:02:58.7  0.043
# 5      5           QJ0240-343     B   1.41  02:40:07.73  -34:34:19.8  0.025
# 6      6           Q0252-3249     B   2.24  02:52:57.85  -32:49.10.1  0.033
# 7      7            B0827+525     B  2.064  08:31:05.37  +52:25:20.4  0.042
# 8      8           Q1120+0195     B   1.47  11:23:20.57  +01:37:48.5  0.037
# 9      9          PKS1145-071     A   1.35  11:47:51.56  -07:24:41.6  0.042
# 10    10          HS1216+5032     B   1.45   12:16:13.4  +50:32:14.0  0.022
# ...

# %%
# Utilizando pandas
df_list = pd.read_html("https://www.cfa.harvard.edu/castles/")
# lista com dfs das tabelas

# %%
del(df_list[0])
len(df_list)
# Out:
# 2

# %%
df_list[1]
# Out:
#     0      1              2  3      4            5            6       7   \
# 0    #  Image    Binary Name  G     zs   RA (J2000)  Dec (J2000)  E(B-V)
# 1    1    NaN  LBQS0015+0239  B   2.45  00:18:11.37  +02:56:39.4   0.030
# 2    2    NaN     MG0023+171  B   0.95  00:25:37.09  +17:28:02.5   0.054
# 3    3    NaN  LBQS0103-2753  B   0.85  01:05:34.74  -27:36:58.5   0.020
# 4    4    NaN      Q0151+048  A   1.91  01:53:53.87  +05:02:58.7   0.043
# 5    5    NaN     QJ0240-343  B   1.41  02:40:07.73  -34:34:19.8   0.025
# 6    6    NaN     Q0252-3249  B   2.24  02:52:57.85  -32:49.10.1   0.033
# 7    7    NaN      B0827+525  B  2.064  08:31:05.37  +52:25:20.4   0.042
# 8    8    NaN     Q1120+0195  B   1.47  11:23:20.57  +01:37:48.5   0.037
# 9    9    NaN    PKS1145-071  A   1.35  11:47:51.56  -07:24:41.6   0.042
# 10  10    NaN    HS1216+5032  B   1.45   12:16:13.4  +50:32:14.0   0.022
# 11  11    NaN     Q1343+2650  A   2.03  13:45:44.06  +26:25:05.9   0.014
# ...
