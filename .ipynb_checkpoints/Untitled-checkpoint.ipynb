# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')
import pandas as pd

# %%
lens_df = pd.read_csv('masterlens.csv')
lens_df.columns
# Out:
# Index(['system_name', 'discovery_date', 'ra_hrs', 'ra_mins', 'ra_secs',
#        'ra_coord', 'dec_degrees', 'dec_arcmin', 'dec_arcsec', 'dec_coord',
#        'lensgrade', 'number_images', 'theta_e', 'theta_e_err', 'z_lens',
#        'z_lens_err', 'z_source', 'z_source_err', 'vdisp', 'vdisp_err'],
#       dtype='object')

# %%
grouped = lens_df.groupby('number_images')['system_name'].count()
grouped.plot.bar(rot=0)
plt.show()

# %%
lens_df.plot(kind='scatter', x='z_source', y='z_lens')

# %%
min(lens_df['z_lens_err']), max(lens_df['z_lens_err'])
# Out:
# (1e-05, 3.0)

# %%
min(lens_df['z_source_err']), max(lens_df['z_source_err'])
# Out:
# (8e-05, 0.57)

# %% [markdown]
# ### Teoria
