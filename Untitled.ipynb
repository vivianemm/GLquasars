# %%
from astroquery.sdss import SDSS

# %%
# psfMag: quasars and stars
# model and cmodel: galaxies (colors and photometry respectively)

query = """select top 1000  objID, type, z, modelMag_u, modelMag_g, modelMag_r, modelMag_i, modelMag_z, 
psfMag_u, psfMag_g, psfMag_r, psfMag_i, psfMag_z from specPhoto where zWarning = 0  ORDER BY NEWID()"""

result = SDSS.query_sql(query)
result = result.to_pandas()

# %%
result
# Out:
#              ra        dec                objID  type         z  modelMag_u  \
# 0    182.795040  30.393740  1237667254551838888     3  0.202079    20.75588
# 1     25.610084  -3.278191  1237678879421170005     6  1.493031    20.45727
# 2    203.150200  29.112775  1237665429166686278     3  0.035471    18.72072
# 3    261.453070  35.110605  1237668352965673765     3  0.570077    24.29112
# 4    203.660700  43.448121  1237661850938441817     6  3.034109    20.92714
# ..          ...        ...                  ...   ...       ...         ...
# 995  354.643080  42.062780  1237663232835519031     6 -0.001048    18.49901
# 996  120.842480  46.176674  1237651495758267061     3  0.608421    24.10897
# 997  244.623430  17.413563  1237671690691280942     6 -0.000138    18.67346
# 998  172.397870  35.618264  1237664336640802952     3  0.119600    19.58763
# 999  154.231250  12.290501  1237661068713197761     3  0.134729    20.73527
#
# ...
